# %%
import numpy as np
import pandas as pd
import datetime
import time
import tqdm
from sklearn.preprocessing import LabelEncoder
import tushare as ts
import warnings
pro = ts.pro_api('700c1d6015ad030ff20bf310c088243da030e6b79a2a1098d58d2614')

# %%
import os
os.chdir('d:/future/panel_informer')

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:Cc15037516974@localhost/future')

# %%
future_list = pro.fut_basic(fut_type='1', list_date = '20000101')

# %%
future_list
# Out:
#          ts_code  symbol exchange     name fut_code  multiplier trade_unit  \
# 0     AP2107.ZCE   AP107     CZCE   苹果2107       AP         NaN          吨
# 1      T1906.CFX   T1906    CFFEX    T1906        T     10000.0          张
# 2     TF1906.CFX  TF1906    CFFEX   TF1906       TF     10000.0          张
# 3     TA1001.ZCE   TA001     CZCE  PTA1001       TA         NaN          吨
# 4     JD1907.DCE  JD1907      DCE   鸡蛋1907       JD         NaN          吨
# ...          ...     ...      ...      ...      ...         ...        ...
# 9847  RU0610.SHF  RU0610     SHFE   橡胶0610       RU         NaN          吨
# 9848  RB1101.SHF  RB1101     SHFE  螺纹钢1101       RB         NaN          吨
# 9849  LC2609.GFE  LC2609     GFEX  碳酸锂2609       LC         NaN       None
# 9850  SI2609.GFE  SI2609     GFEX  工业硅2609       SI         NaN       None
# 9851  PS2609.GFE  PS2609     GFEX  多晶硅2609       PS         NaN       None
#
#       per_unit  quote_unit quote_unit_desc d_mode_desc list_date delist_date  \
# 0         10.0      人民币元/吨         1人民币元/吨        实物交割  20200715    20210714
# 1          1.0        人民币元       0.005人民币元        实物交割  20180917    20190614
# 2          1.0        人民币元       0.005人民币元        实物交割  20180917    20190614
# 3          5.0      人民币元/吨         2人民币元/吨        实物交割  20090119    20100115
# 4          5.0  人民币元/500千克     1人民币元/500千克        实物交割  20180727    20190726
# ...        ...         ...             ...         ...       ...         ...
# 9847      10.0      人民币元/吨         5人民币元/吨        实物交割  20051018    20061016
# 9848      10.0      人民币元/吨         1人民币元/吨        实物交割  20100118    20110117
# 9849       NaN        None            None        None  20250915    20260914
# 9850       NaN        None            None        None  20250915    20260914
# 9851       NaN        None            None        None  20250915    20260914
#
#      d_month last_ddate
# 0     202107   20210719
# 1     201906   20190619
# 2     201906   20190619
# 3     201001   20100119
# 4     201907   20190731
# ...      ...        ...
# 9847  200610   20061023
# 9848  201101   20110124
# 9849  202609   20260917
# 9850  202609   20260917
# 9851  202609   20260917
#
# [9852 rows x 15 columns]

# %%
pro.fut_daily(ts_code = 'IC2309.CFX')
# Out:
#         ts_code trade_date  pre_close  pre_settle    open    high     low  \
# 0    IC2309.CFX   20230915     5709.4      5698.6  5728.0  5748.6  5685.4
# 1    IC2309.CFX   20230914     5712.4      5697.4  5710.2  5713.8  5675.2
# 2    IC2309.CFX   20230913     5769.0      5773.4  5759.8  5772.0  5677.0
# 3    IC2309.CFX   20230912     5760.0      5770.4  5765.8  5789.2  5754.2
# 4    IC2309.CFX   20230911     5697.0      5708.4  5711.4  5806.0  5690.6
# ..          ...        ...        ...         ...     ...     ...     ...
# 154  IC2309.CFX   20230203     6244.8      6249.8  6223.6  6230.2  6148.0
# 155  IC2309.CFX   20230202     6229.4      6228.8  6248.2  6279.2  6218.8
# 156  IC2309.CFX   20230201     6176.8      6182.6  6188.2  6247.2  6174.0
# 157  IC2309.CFX   20230131     6156.6      6150.8  6145.8  6198.0  6137.2
# 158  IC2309.CFX   20230130        NaN      6191.8  6276.8  6276.8  6140.0
#
#       close   settle  change1  change2      vol       amount        oi  \
# 0    5694.6  5695.65     -4.0    -2.95  23482.0  2683556.096       0.0
# 1    5709.4  5698.60     12.0     1.20  48054.0  5476160.884   33060.0
# 2    5712.4  5697.40    -61.0   -76.00  57694.0  6595672.332   64052.0
# 3    5769.0  5773.40     -1.4     3.00  41967.0  4845506.592   86436.0
# 4    5760.0  5770.40     51.6    62.00  65707.0  7565031.728  108701.0
# ..      ...      ...      ...      ...      ...          ...       ...
# 154  6217.4  6214.00    -32.4   -35.80   4931.0   609943.024   12218.0
# 155  6244.8  6249.80     16.0    21.00   5046.0   630932.500   11218.0
# 156  6229.4  6228.80     46.8    46.20   4965.0   617023.620    8677.0
# 157  6176.8  6182.60     26.0    31.80   5238.0   647303.236    7012.0
# 158  6156.6  6150.80    -35.2   -41.00   3967.0   490317.316    3455.0
#
#       oi_chg
# 0   -33060.0
# 1   -30992.0
# 2   -22384.0
# 3   -22265.0
# 4     -930.0
# ..       ...
# 154   1000.0
# 155   2541.0
# 156   1665.0
# 157   3557.0
# 158      NaN
#
# [159 rows x 15 columns]

# %%
def update_data_tosql():
    
    '''
    交易所代码 CFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心 GFEX-广州期货交易所
    '''

    future_list = pro.fut_basic(fut_type='1', list_date = '20000101')
    future_list = future_list.set_index('ts_code')


    for index in tqdm.tqdm(future_list.index):
        # print(index)

        while True:
            try:
                time.sleep(0.2)
                new_data = pro.fut_daily(ts_code = index)
                new_data = new_data.sort_values(by='trade_date')

                new_data.rename(columns = {
                    'pre_close' : 'price_close_lag1',
                    'pre_settle' : 'price_settle_lag1',
                    'open' : 'price_open',
                    'close' : 'price_close',
                    'high' : 'price_high',
                    'low' : 'price_low',
                    'settle' : 'price_settle',
                    'change1' : 'chg_close_close_lag1',
                    'change2' : 'chg_settle_close_lag1',
                    'oi_chg' : 'chg_oi_oi_lag1',
                }, inplace = True)

                for index in ['fut_code', 'list_date', 'delist_date', 'exchange']:
                    new_data[f'{index}'] = new_data['ts_code'].map(future_list[f'{index}'])

                # 相对价格

                for index in ['open', 'high', 'low', 'close', 'settle']:

                    new_data[f'chg_{index}_close_lag1'] = new_data[f'price_{index}'] - new_data['price_close_lag1']
                    new_data[f'pct_chg_{index}_close_lag1'] = new_data[f'chg_{index}_close_lag1'] / new_data['price_close_lag1']

                for index in ['high', 'low', 'close', 'settle']:
                    new_data[f'chg_{index}_open'] = new_data[f'price_{index}'] - new_data['price_open']
                    new_data[f'pct_chg_{index}_open'] = new_data[f'chg_{index}_open'] / new_data['price_open']



                # 历史数据信息
                for i in [5,10,20]:
                    new_data[f'chg_close_close_lag{i}'] = new_data['price_close'] - new_data['price_close'].shift(i)
                    new_data[f'pct_chg_close_close_lag{i}'] = new_data[f'chg_close_close_lag{i}'] / new_data['price_close'].shift(i)

                # 成交量、头寸
                new_data['pct_vol_overall'] = (new_data['vol'] - new_data['vol'].mean())
                new_data['pct_oi_overall'] = (new_data['oi'] - new_data['oi'].mean())


                # 转换日期格式
                new_data['trade_date'] = pd.to_datetime(new_data['trade_date'], format='%Y%m%d')
                new_data['list_date'] = pd.to_datetime(new_data['list_date'], format='%Y%m%d')
                new_data['delist_date'] = pd.to_datetime(new_data['delist_date'], format='%Y%m%d')

                # 计算相对日期、上市天数、剩余天数
                new_data['onlist_day'] = (new_data['trade_date'] - new_data['list_date']).dt.days
                new_data['maturity'] = (new_data['delist_date'] - new_data['trade_date']).dt.days
                new_data['date_count'] = (new_data['trade_date'] - datetime.datetime(2000,1,1,0,0,0)).dt.days

                new_data.to_sql(
                    name = 'panel_price',
                    con = engine,
                    if_exists = 'append',
                    index = False,
                    method = 'multi',
                )
                
                break

            except:
                pass

# %%
update_data_tosql()
# Out:
# 100%|██████████| 9852/9852 [1:31:35<00:00,  1.79it/s]

# %%
def update_data():
    
    '''
    交易所代码 CFFEX-中金所 DCE-大商所 CZCE-郑商所 SHFE-上期所 INE-上海国际能源交易中心 GFEX-广州期货交易所
    '''

    data = pd.DataFrame(columns = ['ts_code', 'trade_date', 'pre_close', 'pre_settle', 'open', 'high', 'low', 'close', 'settle', 'change1', 'change2', 'vol', 'amount', 'oi', 'oi_chg'])

    future_list = pro.fut_basic(fut_type='1', list_date = '20150101')
    future_list = future_list.set_index('ts_code')


    for index in tqdm.tqdm(future_list.index):
        # print(index)

        while True:
            try:
                time.sleep(0.2)
                new_data = pro.fut_daily(ts_code = index)
                new_data = new_data.sort_values(by='trade_date')


                for index in ['fut_code', 'list_date', 'delist_date', 'exchange']:
                    new_data[f'{index}'] = new_data['ts_code'].map(future_list[f'{index}'])

                # 相对价格

                for index in ['open', 'high', 'low', 'close', 'settle']:
                    new_data[f'ch_{index}'] = (new_data[f'{index}'] - new_data['pre_close'])
                    new_data[f'pct_ch_{index}'] = new_data[f'ch_{index}'] / new_data['pre_close'] * 100
                    # 归一化

                    new_data[f'scaled_{index}'] = new_data[f'{index}'] / 76
                    new_data[f'scaled_ch_{index}'] = new_data[f'ch_{index}'] / new_data[f'ch_{index}'].std()

                # 历史数据信息
                for i in [5,10,20]:
                    new_data[f'pct_chg_day{i}'] = (new_data['pre_close'] - new_data['pre_close'].shift(i)) / new_data['pre_close'].shift(i) / i * 100
                # 成交量、头寸
                new_data['ch_vol'] = (new_data['vol'] - new_data['vol'].mean()) / 20000
                new_data['ch_oi'] = (new_data['oi'] - new_data['oi'].mean()) / 34000


                # 转换日期格式
                new_data['trade_date'] = pd.to_datetime(new_data['trade_date'], format='%Y%m%d')
                new_data['list_date'] = pd.to_datetime(new_data['list_date'], format='%Y%m%d')
                new_data['delist_date'] = pd.to_datetime(new_data['delist_date'], format='%Y%m%d')

                # 计算相对日期、上市天数、剩余天数
                new_data['onlist_day'] = (new_data['trade_date'] - new_data['list_date']).dt.days
                new_data['maturity'] = (new_data['delist_date'] - new_data['trade_date']).dt.days

                new_data['scaled_onlist_day'] = new_data['onlist_day'] / 100
                new_data['scaled_maturity'] = new_data['maturity'] / 100

                new_data['date_count'] = (new_data['trade_date'] - datetime.datetime(2015,1,1,0,0,0)).dt.days

                

                data = pd.concat([data, new_data])
                break

            except:
                pass
    
    data.sort_values(by = 'date_count', inplace = True)
    data.dropna(inplace=True)

    label_encoder = LabelEncoder()
    data['fut_code_num'] = label_encoder.fit_transform(data['fut_code'])

    

    data.to_csv('data/futures_data.csv', index = False)

# %%
update_data()
# Out:
# 100%|██████████| 7103/7103 [1:01:51<00:00,  1.91it/s]

# %%
data_set = pd.read_csv('data/futures_data.csv')
data_set
# Out:
#            ts_code  trade_date  pre_close  pre_settle     open     high  \
# 0       FU1601.SHF  2015-02-03     3177.0      3177.0   3018.0   3325.0
# 1       FU1601.SHF  2015-02-04     3325.0      3171.0   3177.0   3177.0
# 2       CU1601.SHF  2015-02-16    41640.0     41410.0  41630.0  41780.0
# 3       ZN1601.SHF  2015-02-16    16390.0     16390.0  16415.0  16425.0
# 4       RU1601.SHF  2015-02-16    14035.0     14025.0  14035.0  14100.0
# ...            ...         ...        ...         ...      ...      ...
# 963780  LU2602.INE  2025-09-11     3351.0      3358.0   3344.0   3354.0
# 963781  CU2601.SHF  2025-09-11    79710.0     79610.0  79800.0  80210.0
# 963782   P2607.DCE  2025-09-11     8888.0      8942.0   8900.0   8900.0
# 963783  FB2511.DCE  2025-09-11     1264.5      1261.5   1270.0   1271.0
# 963784  AO2603.SHF  2025-09-11     3004.0      2995.0   3000.0   3030.0
#
#             low    close   settle  change1  ...  pct_chg_day10  pct_chg_day20  \
# 0        3018.0   3325.0   3171.0    148.0  ...      -0.148837       0.000000
# 1        3177.0   3177.0   3177.0      6.0  ...       0.310078       0.232924
# 2       41330.0  41780.0  41500.0    370.0  ...       0.776398       0.182972
# 3       16415.0  16425.0  16420.0     35.0  ...       0.176964       0.216423
# 4       13865.0  14085.0  14010.0     60.0  ...       0.632576       0.360963
# ...         ...      ...      ...      ...  ...            ...            ...
# 963780   3327.0   3350.0   3338.0     -8.0  ...      -0.236014      -0.073508
# 963781  79800.0  80110.0  80040.0    500.0  ...       0.073297       0.016994
# 963782   8840.0   8840.0   8868.0   -102.0  ...      -0.117856      -0.051225
# 963783   1260.0   1262.5   1263.0      1.0  ...      -0.094007      -0.098837
# 963784   2994.0   3018.0   3008.0     23.0  ...      -0.118421      -0.413740
#
#            ch_vol     ch_oi  onlist_day maturity scaled_onlist_day  \
# 0        0.000144  0.000060        29.0    331.0              0.29
# 1        0.000144 -0.000058        30.0    330.0              0.30
# 2       -4.261809 -1.578198        31.0    333.0              0.31
# 3       -4.252432 -0.943958        31.0    333.0              0.31
# 4      -13.717875 -2.822790        31.0    333.0              0.31
# ...           ...       ...         ...      ...               ...
# 963780   0.030917  0.061802       218.0    141.0              2.18
# 963781   0.141602  0.478339       238.0    126.0              2.38
# 963782   0.000471  0.002382        58.0    306.0              0.58
# 963783   0.028743  0.046229       300.0     64.0              3.00
# 963784   0.024712  0.151991       177.0    186.0              1.77
#
#        scaled_maturity date_count  fut_code_num
# 0                 3.31       33.0            24
# 1                 3.30       34.0            24
# 2                 3.33       46.0            17
# 3                 3.33       46.0            84
# 4                 3.33       46.0            62
# ...                ...        ...           ...
# 963780            1.41     3906.0            40
# 963781            1.26     3906.0            17
# 963782            3.06     3906.0            46
# 963783            0.64     3906.0            22
# 963784            1.86     3906.0             4
#
# [963785 rows x 50 columns]
